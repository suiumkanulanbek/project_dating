# %% [markdown]
# ***How Couples Meet and Stay Together 2022
# Main content start** Dataset by Stanford University

# %% [markdown]
# Source: https://data.stanford.edu/hcmst2017

# %% [markdown]
# Dataset Documentation: https://stacks.stanford.edu/file/druid:hg921sg6829/HCMST%202017%20to%202022%20v2.2%20codebook.pdf

# %%
# !pip install pyreadstat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.3/609.3 kB 6.5 MB/s eta 0:00:00:00:0100:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pyreadstat

df, meta = pyreadstat.read_sav("hcmst.sav")
df.to_csv("hcmst.csv", index=False)

# %%
df
# Out:
#       caseid_new  w3_Weight  w3_Weight_LGB  w3_combo_weight  \
# 0        53001.0     0.4422            NaN         0.495308
# 1        71609.0     0.8284            NaN         0.927891
# 2       106983.0     0.8255            NaN         0.924643
# 3       121759.0        NaN            NaN              NaN
# 4       158083.0     0.8810            NaN         0.986809
# ...          ...        ...            ...              ...
# 3505   2967957.0        NaN            NaN              NaN
# 3506   2968357.0        NaN            NaN              NaN
# 3507   2968971.0        NaN            NaN              NaN
# 3508   2969933.0        NaN            NaN              NaN
# 3509   2972135.0        NaN            NaN              NaN
#
#       w3_attrition_adj_weight  w2_weight_genpop  w2_weight_LGB  \
# 0                    0.400185            0.3856            NaN
# 1                    0.879258            0.9196            NaN
# ...

# %%
df.head()
# Out:
#    caseid_new  w3_Weight  w3_Weight_LGB  w3_combo_weight  \
# 0     53001.0     0.4422            NaN         0.495308
# 1     71609.0     0.8284            NaN         0.927891
# 2    106983.0     0.8255            NaN         0.924643
# 3    121759.0        NaN            NaN              NaN
# 4    158083.0     0.8810            NaN         0.986809
#
#    w3_attrition_adj_weight  w2_weight_genpop  w2_weight_LGB  w2_combo_weight  \
# 0                 0.400185            0.3856            NaN         0.437670
# 1                 0.879258            0.9196            NaN         1.043778
# 2                 0.706467            0.7748            NaN         0.879425
# 3                      NaN            0.9177            NaN         1.041622
# 4                 0.655467            0.8697            NaN         0.987140
#
#    w2_attrition_adj_weights  w1_weight_combo  ...  p20_pppa1634  p20_pppa1902  \
# ...

# %%
covid = df["w3_coronavirus_effect_dating"].value_counts(normalize=True) * 100
covid = covid.round(2)


print(covid)
# Out:
# w3_coronavirus_effect_dating
# 2.0    64.85
# 3.0    33.05
# 1.0     2.09
# Name: proportion, dtype: float64

# %% [markdown]
# **From Documentation**
# Base: Section B
# w3_coronavirus_effect_dating_B [S]
# How has the coronavirus (also known as COVID-19) pandemic affected your ability to
# meet new people face-to-face for romance, dating, or sex?
# 1. It is EASIER to meet people face-to-face Now than it was before the pandemic
# 2. No change
# 3. It is HARDER to meet people face-to-face Now than it was before the pandemic

# %%
covid_1 = df["w3_q24_internet_dating"].value_counts(normalize=True) * 100
covid_1 = covid_1.round(2)


print(covid_1)
# Out:
# w3_q24_internet_dating
# 0.0    82.22
# 1.0    17.78
# Name: proportion, dtype: float64

# %%
covid_2 = df["w3_duration"].value_counts(normalize=True) * 100
covid_2 = covid_2.round(2)


print(covid_2)
# Out:
# w3_duration
# 5.52     0.41
# 8.55     0.41
# 4.53     0.35
# 7.21     0.35
# 7.41     0.35
#          ...
# 4.90     0.06
# 8.24     0.06
# 16.18    0.06
# 16.54    0.06
# 27.88    0.06
# Name: proportion, Length: 1088, dtype: float64

# %%
freq = df["w3_how_many_corona"].value_counts(normalize=True) * 100
freq = freq.round(2)


print(freq)
# Out:
# w3_how_many_corona
# 2.0    58.69
# 3.0    37.32
# 1.0     3.99
# Name: proportion, dtype: float64

# %% [markdown]
# **Tabulation: Freq. Numeric Label 14**
# 1 During the pandemic, I have
# &nbsp;&nbsp;&nbsp;been texting and communicating
# &nbsp;&nbsp;&nbsp;with MORE potential partners
# **206**
#
# 2 During the pandemic, I have
# &nbsp;&nbsp;&nbsp;been texting and communicating
# &nbsp;&nbsp;&nbsp;with the SAME number of
# &nbsp;&nbsp;&nbsp;potential partners
# **131**
#
# 3 During the pandemic, I have
# &nbsp;&nbsp;&nbsp;been texting and communicating
# &nbsp;&nbsp;&nbsp;with FEWER potential partners
# **3,159**

# %%
app = df["w3_app_use"].value_counts(normalize=True) * 100
app = app.round(2)


print(app)
# Out:
# w3_app_use
# 2.0    71.86
# 3.0    23.22
# 1.0     4.92
# Name: proportion, dtype: float64

# %% [markdown]
# **Type:** Numeric (byte)
# **Label:** `W3_APP_U`
# **Range:** [1, 3] **Units:** 1
# **Unique values:** 3 **Missing:** 3,144 / 3,510
#
# **Tabulation:**
#
# 18 1 *I am using dating apps and*
#     *online dating More than before*
#
# 263 2 *About the same*
#
# 85 3 *I am using dating apps and*
#     *online dating Less than before*

# %%
#w3_q24_internet_dating

internet = df["w3_q24_internet_dating"].value_counts(normalize=True) * 100
internet = internet.round(2)


print(internet)
# Out:
# w3_q24_internet_dating
# 0.0    82.22
# 1.0    17.78
# Name: proportion, dtype: float64

# %% [markdown]
# **Tabulation:**
# **Numeric** **Label**
#   0   *no*
#   1   *yes*

# %%
#w3_q24_internet_org

internet_org = df["w3_q24_internet_org"].value_counts(normalize=True) * 100
internet_org = internet_org.round(2)


print(internet_org)
# Out:
# w3_q24_internet_org
# 0.0    100.0
# Name: proportion, dtype: float64

# %%
#w3_q24_met_online

met_online = df["w3_q24_met_online"].value_counts(normalize=True) * 100
met_online = met_online.round(2)


print(met_online)
# Out:
# w3_q24_met_online
# 0.0    71.11
# 1.0    28.89
# Name: proportion, dtype: float64

# %% [markdown]
# **Numeric** **Label**
# 0       *no*
# 1       *yes*
